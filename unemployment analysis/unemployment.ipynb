# %% [markdown]
# UNEMPLOYMENT ANALYSIS
#
# ---

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.express as px
import plotly.graph_objects as go
import datetime as dt
import calendar

# %% [markdown]
# **Table of content**
# *  Reading CSV File
# *  Describing Data
# *  Importing Libraries
# *  Analyzing Data by barplots
# *  Analyzing Data by boxplot
# *  Analyzing Data by scatterplot

# %%
df = pd.read_csv('/content/Unemployment in India.csv')

# %% [markdown]
# Reading CSV File

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                          3.650000
# 1    Andhra Pradesh   30-06-2019    Monthly                          3.050000
# 2    Andhra Pradesh   31-07-2019    Monthly                          3.750000
# 3    Andhra Pradesh   31-08-2019    Monthly                          3.320000
# 4    Andhra Pradesh   30-09-2019    Monthly                          5.170000
# ..              ...          ...        ...                               ...
# 755  Andhra Pradesh   31-10-2042    Monthly                        199.269804
# 756  Andhra Pradesh   30-11-2042    Monthly                        199.760196
# 757  Andhra Pradesh   31-12-2042    Monthly                        200.250588
# 758  Andhra Pradesh   31-01-2043    Monthly                        200.740980
# 759  Andhra Pradesh   29-02-2043    Monthly                        201.231372
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0            11999139.00                                 43.240000  Rural
# 1            11755881.00                                 42.050000  Rural
# 2            12086707.00                                 43.500000  Rural
# 3            12285693.00                                 43.970000  Rural
# 4            12256762.00                                 44.680000  Rural
# ..                   ...                                       ...    ...
# 755         -68071488.99                                157.373529  Urban
# 756         -68257248.31                                157.682794  Urban
# 757         -68443007.63                                157.992059  Urban
# 758         -68628766.95                                158.301323  Urban
# 759         -68814526.27                                158.610588  Urban
#
# [760 rows x 7 columns]

# %%
df.shape
# Out:
# (760, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    760 non-null    object
#  1    Date                                     760 non-null    object
#  2    Frequency                                760 non-null    object
#  3    Estimated Unemployment Rate (%)          760 non-null    float64
#  4    Estimated Employed                       760 non-null    float64
#  5    Estimated Labour Participation Rate (%)  760 non-null    float64
#  6   Area                                      760 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.7+ KB

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        760.000000         7.600000e+02
# mean                          59.303854        -1.189144e+07
# std                           62.463652         2.696773e+07
# min                            0.000000        -6.881453e+07
# 25%                            6.787500        -3.356670e+07
# 50%                           26.896961         1.402700e+05
# 75%                          108.179461         6.878780e+06
# max                          201.231372         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                760.000000
# mean                                  72.056166
# std                                   37.375021
# min                                   13.330000
# 25%                                   42.160000
# 50%                                   54.299191
# 75%                                   99.927610
# max                                  158.610588

# %%
x=df['Region']

# %%
x
# Out:
# 0      Andhra Pradesh
# 1      Andhra Pradesh
# 2      Andhra Pradesh
# 3      Andhra Pradesh
# 4      Andhra Pradesh
#             ...
# 755    Andhra Pradesh
# 756    Andhra Pradesh
# 757    Andhra Pradesh
# 758    Andhra Pradesh
# 759    Andhra Pradesh
# Name: Region, Length: 760, dtype: object

# %%
df2=df.iloc[:,3]

# %%
df2
# Out:
# 0        3.650000
# 1        3.050000
# 2        3.750000
# 3        3.320000
# 4        5.170000
#           ...
# 755    199.269804
# 756    199.760196
# 757    200.250588
# 758    200.740980
# 759    201.231372
# Name:  Estimated Unemployment Rate (%), Length: 760, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    760 non-null    object
#  1    Date                                     760 non-null    object
#  2    Frequency                                760 non-null    object
#  3    Estimated Unemployment Rate (%)          760 non-null    float64
#  4    Estimated Employed                       760 non-null    float64
#  5    Estimated Labour Participation Rate (%)  760 non-null    float64
#  6   Area                                      760 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.7+ KB

# %%
round(df.describe().T)
# Out:
#                                           count        mean         std  \
#  Estimated Unemployment Rate (%)          760.0        59.0        62.0
#  Estimated Employed                       760.0 -11891439.0  26967734.0
#  Estimated Labour Participation Rate (%)  760.0        72.0        37.0
#
#                                                  min         25%       50%  \
#  Estimated Unemployment Rate (%)                 0.0         7.0      27.0
#  Estimated Employed                      -68814526.0 -33566695.0  140270.0
#  Estimated Labour Participation Rate (%)        13.0        42.0      54.0
#
#                                                 75%         max
#  Estimated Unemployment Rate (%)              108.0       201.0
#  Estimated Employed                       6878780.0  45777509.0
#  Estimated Labour Participation Rate (%)      100.0       159.0

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %% [markdown]
# Analyzing Data By Boxplot

# %%
fg = px.box(df,x='Region',y=' Estimated Unemployment Rate (%)',color='Region',title='Unemployment rate',animation_frame=' Date',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b5ce4fad-cca0-4d9a-99e2-acc0decc0248" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5ce4fad-cca0-4d9a-99e2-acc0decc0248")) {                    Plotly.newPlot(                        "b5ce4fad-cca0-4d9a-99e2-acc0decc0248",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa"},"name":"Andhra Pradesh","notched":false,"offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["Andhra Pradesh","Andhra Pradesh"],"x0":" ","xaxis":"x","y":[3.65,6.09],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#EF553B"},"name":"Assam","notched":false,"offsetgroup":"Assam","orientation":"v","showlegend":true,"x":["Assam","Assam"],"x0":" ","xaxis":"x","y":[4.29,7.87],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#00cc96"},"name":"Bihar","notched":false,"offsetgroup":"Bihar","orientation":"v","showlegend":true,"x":["Bihar"],"x0":" ","xaxis":"x","y":[9.27],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa"},"name":"Chhattisgarh","notched":false,"offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"x":["Chhattisgarh"],"x0":" ","xaxis":"x","y":[9.82],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FFA15A"},"name":"Delhi","notched":false,"offsetgroup":"Delhi","orientation":"v","showlegend":true,"x":["Delhi"],"x0":" ","xaxis":"x","y":[12.56],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#19d3f3"},"name":"Goa","notched":false,"offsetgroup":"Goa","orientation":"v","showlegend":true,"x":["Goa"],"x0":" ","xaxis":"x","y":[2.91],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#FF6692"},"name":"Gujarat","notched":false,"offsetgroup":"Gujarat","orientation":"v","showlegend":true,"x":["Gujarat"],"x0":" ","xaxis":"x","y":[2.88],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Haryana","marker":{"color":"#B6E880"},"name":"Haryana","notched":false,"offsetgroup":"Haryana","orientation":"v","showlegend":true,"x":["Haryana"],"x0":" ","xaxis":"x","y":[14.54],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Himachal Pradesh","marker":{"color":"#FF97FF"},"name":"Himachal Pradesh","notched":false,"offsetgroup":"Himachal Pradesh","orientation":"v","showlegend":true,"x":["Himachal Pradesh"],"x0":" ","xaxis":"x","y":[13.68],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra> ...

# %%
fg = px.scatter(df,x='Region',y=' Estimated Unemployment Rate (%)',color='Region',title='Unemployment rate',animation_frame=' Date',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="daee4301-5bd8-4392-a556-b4e6c02c9f8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daee4301-5bd8-4392-a556-b4e6c02c9f8b")) {                    Plotly.newPlot(                        "daee4301-5bd8-4392-a556-b4e6c02c9f8b",                        [{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["Andhra Pradesh","Andhra Pradesh"],"xaxis":"x","y":[3.65,6.09],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"x":["Assam","Assam"],"xaxis":"x","y":[4.29,7.87],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"x":["Bihar"],"xaxis":"x","y":[9.27],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"x":["Chhattisgarh"],"xaxis":"x","y":[9.82],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"x":["Delhi"],"xaxis":"x","y":[12.56],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"x":["Goa"],"xaxis":"x","y":[2.91],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"x":["Gujarat"],"xaxis":"x","y":[2.88],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Haryana","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Haryana","orientation":"v","showlegend":true,"x":["Haryana"],"xaxis":"x","y":[14.54],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Himachal Pradesh","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Himachal Pradesh","orientation":"v","showlegend":true,"x":["Himachal Pradesh"],"xaxis":"x","y":[13.68],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Jammu & Kashmir","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Jammu & Kashmir","orientation":"v","showlegend":true,"x":["Jammu & Kashmir"],"xaxis":"x","y":[12.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=%{x}<br> Date= 31-05-2019<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Jharkhand","marker":{"color":"#636efa","symbol":"circl ...
